# %%
# %matplotlib inline
import pandas
import seaborn as sns
import numpy as np
sns.set(color_codes=True)

# %%
data = pandas.read_csv('titanic.csv', index_col='PassengerId')

# %% [markdown]
# 1 . Men/Women

# %%
data["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# 2 . Survived

# %%
data["Survived"].value_counts(normalize=True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %% [markdown]
# Graph

# %%
sns.stripplot(x="Pclass", y="Age", data=data, jitter=True)

# %% [markdown]
# 3 . classes

# %%
data["Pclass"].value_counts(normalize=True)
# Out:
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: Pclass, dtype: float64

# %% [markdown]
# 4 . age mean/median

# %%
data["Age"].mean()
# Out:
# 29.69911764705882

# %%
data["Age"].median()
# Out:
# 28.0

# %% [markdown]
# 5 . correlation

# %%
data["Parch"].corr(data["SibSp"], method='pearson')
# Out:
# 0.41483769862015601

# %%
sns.jointplot(x="Parch", y="SibSp", data=data)

# %% [markdown]
# 6 women name

# %%
data[data["Sex"]=="female"]["Name"].str.split(pat=", ", expand=True)[1].str.split(pat=" ").str[1].value_counts().head()
